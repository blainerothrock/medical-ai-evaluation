# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os, sys, time

# url for 510k SaMD details page
eq_url = 'https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID='
# url for De Novo SaMD details page
denovo_url = 'https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id='
# url for product codes
product_code_url = 'https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode='

# %%
# download base submission data (requires manual table extraction to kickstart)
#   - TODO: provide instructions for table extraction.

cols = []
data = []

soup = BeautifulSoup(open('aiml_samd_09222021.htm'))
for header in soup.findAll("th"):
    cols.append(header.string.lower().replace(' ', "_")) 

cols.append('submission_type')

for i, row in enumerate(soup.findAll('tr')):
    if i == 0: continue
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.string)

    if row_data[1].startswith('K'):
        row_data.append('510k')
    elif row_data[1].startswith('DEN'):
        row_data.append('DENOVO')
    else:
        row_data.append(None)
        
    data.append(row_data)

df_submissions = pd.DataFrame(data, columns=cols)

product_codes = df_submissions.primary_product_code.unique().tolist()
print(product_codes)

df_submissions.head(10)
# Out:
# ['JAK', 'LLZ', 'MXD', 'PIB', 'QPF', 'QAS', 'KPS', 'QIH', 'QKB', 'MUJ', 'QFM', 'QNP', 'MQB', 'QOK', 'OEB', 'LNH', 'QME', 'POK', 'QNV', 'NQQ', 'QNL', 'QDQ', 'POV', 'JOY', 'DQD', 'QJU', 'DQK', 'PRH', 'IYN', 'MLO', 'QBS', 'IYO', 'DSI', 'DPS', 'IYE', 'MWI', 'BZG', 'QEK', 'HAW', 'QJB', 'MRZ', 'MUD', 'GKZ', 'JAA', 'PIW', 'GXY', 'PLB', 'PJA', 'JFY', 'PBH', 'QER', 'QAQ', 'PPU', 'OZE', 'DQA', 'DXH', 'NDC', 'QEA', 'POS', 'PCS', 'OMB', 'GWN', 'JIL', 'OLO', 'QCC', 'NAY', 'OBH', 'PNN', 'DSB', 'DRG', 'DSH', 'DPT', 'MNR', 'PTA', 'OLZ', 'NBW', 'MYN', 'PBZ', 'OWB', 'NFJ', 'KPR', 'PEX', 'OIW', 'MHX']
#   date_of_final_decision submission_number  \
# 0             06/17/2021           K203514
# 1             06/16/2021           K202718
# 2             06/11/2021           K210484
# 3             06/10/2021           K203629
# 4             06/02/2021         DEN200069
# 5             05/19/2021           K210237
# 6             04/30/2021           K210001
# 7             04/23/2021           K203314
# 8             04/23/2021           K203502
# 9             04/21/2021           K210556
#
#                                               device  \
# 0                                   Precise Position
# 1                        Qmenta Care Platform Family
# 2  LINQ II Insertable Cardiac Monitor, Zelda AI E...
# 3                                             IDx-DR
# 4                           Cognoa Asd Diagnosis Aid
# 5                                         CINA CHEST
# 6                                          HYPER AiR
# 7                Cartesion Prime (PCD-1000A/3) V10.8
# 8                                       MEDO-Thyroid
# 9                                   Preview Shoulder
#
#                                        company    panel_(lead)  \
# 0        Philips Healthcare (Suzhou) Co., Ltd.       Radiology
# 1               Mint Labs, Inc., D/B/A. QMENTA       Radiology
# 2                              Medtronic, Inc.  Cardiovascular
# 3                     Digital Diagnostics Inc.      Ophthalmic
# 4                                 Cognoa, Inc.       Neurology
# 5                                  Avicenna.AI       Radiology
# 6  Shanghai United Imaging Healthcare Co.,Ltd.       Radiology
# 7            Canon Medical Systems Corporation       Radiology
# 8                            MEDO DX Pte. Ltd.       Radiology
# 9                 Genesis Software Innovations       Radiology
#
#   primary_product_code submission_type
# 0                  JAK            510k
# 1                  LLZ            510k
# 2                  MXD            510k
# 3                  PIB            510k
# 4                  QPF          DENOVO
# 5                  QAS            510k
# 6                  KPS            510k
# 7                  KPS            510k
# 8                  QIH            510k
# 9                  QIH            510k

# %%
# download submission pages
for i, row in df_submissions.iterrows():
    if row.submission_type == '510k':
        url = eq_url + row.submission_number
    if row.submission_type == 'DENOVO':
        url = denovo_url + row.submission_number 
    
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    data_path = os.path.join('data', 'submission_html')
    os.makedirs(data_path, exist_ok=True)

    with open(os.path.join(data_path, f'{row.submission_number}.htm'), 'w') as f:
        f.write(str(soup))

    print(url, f'{i+1}/{len(df_submissions)}')
# Out:
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203514 0/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202718 1/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K210484 2/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203629 3/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN200069 4/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K210237 5/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K210001 6/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203314 7/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203502 8/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K210556 9/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203610 10/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203469 11/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203517 12/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202992 13/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN200055 14/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202441 15/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN200038 16/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203258 17/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203443 18/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K210071 19/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN200019 20/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203225 21/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K210209 22/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203235 23/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203256 24/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202300 25/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN200022 26/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202990 27/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203578 28/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202212 29/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203103 30/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K210053 31/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201411 32/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193271 33/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202700 34/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201836 35/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200717 36/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202414 37/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203508 38/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202229 39/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201555 40/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201745 41/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203042 42/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201039 43/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202487 44/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200873 45/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K203169 46/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201019 47/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193306 48/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193289 49/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193562 50/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200750 51/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200323 52/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202013 53/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202089 54/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200595 55/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201710 56/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202501 57/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193631 58/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201301 59/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K202280 60/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192051 61/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201103 62/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200569 63/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200852 64/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201992 65/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201298 66/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201369 67/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192665 68/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200708 69/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200851 70/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200833 71/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200714 72/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201020 73/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201632 74/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201232 75/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201444 76/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200990 77/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K201310 78/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193210 79/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200667 80/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193283 81/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193417 82/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200743 83/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200621 84/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200497 85/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200905 86/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193097 87/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192969 88/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193294 89/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193073 90/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192880 91/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193252 92/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200760 93/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200855 94/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200232 95/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193298 96/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193290 97/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200921 98/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200356 99/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200980 100/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192901 101/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193176 102/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193220 103/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193351 104/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200755 105/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192167 106/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193282 107/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193300 108/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193087 109/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192732 110/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193518 111/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192437 112/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192854 113/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193281 114/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K200036 115/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193658 116/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193267 117/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192388 118/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192574 119/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193216 120/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193229 121/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191550 122/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191556 123/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191928 124/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192962 125/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192832 126/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192973 127/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193248 128/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192828 129/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193178 130/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192377 131/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN190040 132/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193109 133/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192956 134/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191125 135/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192004 136/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183089 137/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191647 138/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192383 139/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192763 140/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192531 141/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K193170 142/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192571 143/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192287 144/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192442 145/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192279 146/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192945 147/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192320 148/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190529 149/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191278 150/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191171 151/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191026 152/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190868 153/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192109 154/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190013 155/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190334 156/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190898 157/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183274 158/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192455 159/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191493 160/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191713 161/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191994 162/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192065 163/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191688 164/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192304 165/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183370 166/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190815 167/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183268 168/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191179 169/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183489 170/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K192107 171/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183282 172/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190925 173/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183182 174/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191262 175/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182384 176/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183271 177/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182798 178/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191585 179/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182875 180/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183322 181/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191384 182/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182901  183/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190442 184/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190017 185/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191194 186/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190387 187/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183460 188/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190424 189/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183046 190/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190896 191/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K191083 192/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183646 193/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183648 194/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190764 195/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190362 196/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182513 197/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181988 198/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K190072 199/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183202 200/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183204 201/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181352 202/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183019 203/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181823 204/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183285 205/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182344 206/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183704 207/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181916 208/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183272 209/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183231 210/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182456 211/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183133 212/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN170091 213/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180867 214/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182130 215/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182564 216/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K183012 217/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181861 218/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182149 219/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182419 220/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182790 221/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173749 222/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182373 223/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182218 224/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182336 225/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182181 226/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181704 227/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181247 228/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180432 229/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180343 230/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181939 231/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182616 232/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182177 233/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181685 234/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182034 235/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181892 236/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182112 237/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173872 238/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181771 239/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182310 240/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181502 241/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180647 242/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173444 243/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173327 244/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181572 245/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K181574 246/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180038 247/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173574 248/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173780 249/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K172983 250/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN170043 251/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173821 252/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180163 253/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN180005 254/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173810 255/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180799 256/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180599 257/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K172959 258/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180161 259/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180126 260/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN180001 261/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180589 262/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN160044 263/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173939 264/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173605 265/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K170540 266/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN170073 267/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K180091 268/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173542 269/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173588 270/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K171122 271/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K171328 272/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K171056 273/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K173420 274/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K172507 275/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163694 276/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K172803 277/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163623 278/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K171936 279/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K172356 280/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K172385 281/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K170981 282/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163339 283/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K172122 284/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K171315 285/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN170022 286/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K170568 287/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K170747 288/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K170250 289/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K170172 290/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163622 291/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163665 292/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K170069 293/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN160026 294/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K162627 295/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K162855 296/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K162830 297/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163013 298/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163253 299/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161959 300/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161322 301/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161834 302/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163138 303/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K163138 304/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K160401 305/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161068 306/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161625 307/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161201 308/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161148 309/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K160338 310/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K161382 311/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K160016 312/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K160088 313/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K153351 314/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K153427 315/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K150817 316/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K150102 317/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K142512 318/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K142918 319/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K141922 320/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN140025 321/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K142037 322/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K141069 323/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K141480 324/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K133649 325/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K133259 326/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K130831 327/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/denovo.cfm?id=DEN130013 328/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K120771 329/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K123526 330/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K120489 331/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K120161 332/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K111776 333/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K102778 334/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K092116 335/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K080595 336/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K082483 337/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K081140 338/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K080762 339/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K033840 340/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K003301 341/343
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K955841 342/343

# %%
# extract submission tables
def extract_fda_data_table(data_path, id, table_chars):
    soup = BeautifulSoup(open(os.path.join(data_path, f'{id}.htm')))
    t = soup.find('table', table_chars)

    if t is not None:
        with open(os.path.join(os.path.join(data_path, f'{id}_table.htm')), 'w') as f:
            f.write(str(t.prettify()))

data_path = os.path.join('data', 'submission_html')
os.makedirs(data_path, exist_ok=True)
for i, row in df_submissions.iterrows():
    if row.submission_type == 'DENOVO':
        extract_fda_data_table(
            data_path, 
            row.submission_number, 
            {'style': 'text-transform: capitalize; table-layout:fixed; width:500px'}
        )
    if row.submission_type == '510k':
        extract_fda_data_table(
            data_path,
            row.submission_number,
            {'style': 'text-transform: none'}
        )

data_path = os.path.join('data', 'product_code_html')
os.makedirs(data_path, exist_ok=True)
for code in product_codes: 
    extract_fda_data_table(
        data_path, 
        code, 
        {'width': '600', 'cellspacing': '5'}
    )

# %%
# generate full submission table

# extract submission headers

df_submission_denovo = df_submissions[df_submissions.submission_type == 'DENOVO']

submission_denovo_headers = set()
for i, row in df_submission_denovo.iterrows():
    soup = BeautifulSoup(open(os.path.join('data', 'submission_html', f'{row.submission_number}_table.htm')))
    headers = []
    for header in soup.findAll('th'):
        headers.append(header.string.replace('\n', '').strip())
    submission_denovo_headers = submission_denovo_headers | set(headers)

submission_denovo_headers = list(submission_denovo_headers)

denovo_data = []
for i, sub in df_submission_denovo.iterrows():
    soup = BeautifulSoup(open(os.path.join('data', 'submission_html', f'{sub.submission_number}_table.htm')))
    obj = { key: None for key in submission_denovo_headers }

    table = soup.table
    # print(table)
    for row in table.findAll('tr'):
        try: 
            header = row.th.string.replace('\n', '').strip()
            data = row.td
            
            if data.a is not None:
                link = data.a.get('href')
                url = requests.compat.urlparse(link)

                print(url)

                data = data = f'[{data.get_text()}]'

            elif data.table is not None:
                # data = ' '.join([x.text for x in data.table.findAll('td')])
                data = data.get_text()
            else:
                data = data.get_text()

            data = data \
                .replace('\r', '') \
                .replace('\n', '') \
                .replace('\t', '') \
                .strip()

            obj[header] = data
        except: continue
    
    denovo_data.append(obj)
    
df_denovo = pd.DataFrame.from_dict(denovo_data)
df_denovo.head()
# Out:
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QPF', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=882.1491', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QPF', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf20/DEN200069.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QNP', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=876.1520', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QNP', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf20/DEN200055.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QOK', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=870.2786', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QOK', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf20/DEN200038.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN200038.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QME', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=870.2785', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QME', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf20/DEN200019.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QNV', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=870.2220', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QNV', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf20/DEN200022.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QJU', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=892.2100', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QJU', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf19/DEN190040.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN190040.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QEA', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=882.1455', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QEA', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf17/DEN170091.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN170091.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QCC', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=862.1358', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QCC', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf17/DEN170043.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN170043.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QBS', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=892.2090', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QBS', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf18/DEN180005.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN180005.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PIB', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=886.1100', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PIB', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf18/DEN180001.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN180001.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QAQ', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=870.2210', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QAQ', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf16/DEN160044.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN160044.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QAS', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=892.2080', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=QAS', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf17/DEN170073.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN170073.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=POK', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=892.2060', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=POK', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf17/DEN170022.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN170022.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PTA', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=866.5950', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PTA', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf16/DEN160026.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN160026.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PIW', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=882.1450', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PIW', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf14/DEN140025.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/DEN140025.pdf', params='', query='', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PEX', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfcfr/cfrsearch.cfm', params='', query='fr=866.3361', fragment='')
# ParseResult(scheme='', netloc='', path='/scripts/cdrh/cfdocs/cfpcd/classification.cfm', params='', query='start_search=1&productcode=PEX', fragment='')
# ParseResult(scheme='https', netloc='www.accessdata.fda.gov', path='/cdrh_docs/pdf12/K124067.pdf', params='', query='', fragment='')
# ParseResult(scheme='http', netloc='www.accessdata.fda.gov', path='/cdrh_docs/reviews/K124067.pdf', params='', query='', fragment='')
#   De Novo Number Classification Advisory Committee                 FDA Review  \
# 0      DEN200069                         Neurology                       None
# 1      DEN200055          Gastroenterology/Urology                       None
# 2      DEN200038                    Cardiovascular  [    Decision Summary   ]
# 3      DEN200019                    Cardiovascular                       None
# 4      DEN200022                    Cardiovascular                       None
#
#    Regulation Number                                          Requester  \
# 0  [    882.1491   ]  Cognoa, Inc.           2185 park blvd.        ...
# 1  [    876.1520   ]  Cosmo Artificial Intelligence - AI, LTD       ...
# 2  [    870.2786   ]  ContinUse Biometrics Ltd.           habarzel 3...
# 3  [    870.2785   ]  Oxehealth Limited           magdalen center no...
# 4  [    870.2220   ]  Fifth Eye Inc.           110 miller avenue, su...
#
#                                          Device Name 510(K) Number    Type  \
# 0                           Cognoa ASD Diagnosis Aid          None  Direct
# 1                                          GI Genius          None  Direct
# 2  Gili Pro BioSensor (also known as “Gili BioSen...          None  Direct
# 3                              Oxehealth Vital Signs          None  Direct
# 4         Analytic for Hemodynamic Instability (AHI)          None  Direct
#
#   Date Received Expedited Review Review Advisory Committee        Decision  \
# 0    11/03/2020             None                 Neurology  granted (DENG)
# 1    09/08/2020             None  Gastroenterology/Urology  granted (DENG)
# 2    06/12/2020             None            Cardiovascular  granted (DENG)
# 3    03/27/2020             None            Cardiovascular  granted (DENG)
# 4    04/03/2020             None            Cardiovascular  granted (DENG)
#
#                           Device Classification Name Decision Date  \
# 0  [    pediatric autism spectrum disorder diagno...    06/02/2021
# 1  [    gastrointesinal lesion software detection...    04/09/2021
# 2  [    hardware and software for optical camera-...    04/01/2021
# 3  [    software for optical camera-based measure...    03/26/2021
# 4  [    adjunctive hemodynamic indicator with dec...    03/01/2021
#
#             Reclassification Order             Contact  \
# 0  [    Reclassification Order   ]    sophie  dessalle
# 1  [    Reclassification Order   ]  steven a. kradjian
# 2  [    Reclassification Order   ]        sagi  polani
# 3  [    Reclassification Order   ]   hugh  lloyd-jukes
# 4  [    Reclassification Order   ]    jennifer a baird
#
#   Classification Product Code
# 0          [       QPF      ]
# 1          [       QNP      ]
# 2          [       QOK      ]
# 3          [       QME      ]
# 4          [       QNV      ]

# %%
df_submission_510k = df_submissions[df_submissions.submission_type == '510k']
submission_510k_headers = set()
for i, row in df_submission_510k.iterrows():
    soup = BeautifulSoup(open(os.path.join('data', 'submission_html', f'{row.submission_number}_table.htm')))
    headers = []
    for header in soup.findAll('th'):
        headers.append(header.string)
    submission_510k_headers = submission_510k_headers | set(headers)

print(list(submission_510k_headers))

# %%
# download submission pdfs (DOES NOT WORK, LINK IS DYNAMIC BY FIRST SUB DATE?)
# import requests

# url = 'http://www.hrecos.org//images/Data/forweb/HRTVBSH.Metadata.pdf'
# r = requests.get(url, stream=True)

# with open('/tmp/metadata.pdf', 'wb') as fd:
#     for chunk in r.iter_content(chunk_size):
#         fd.write(chunk)

for i, row in df_submissions.iterrows():

    year = row.date_of_final_decision[-2:]

    url = f'https://www.accessdata.fda.gov/cdrh_docs/pdf{year}/{row.submission_number}.pdf'
    res = requests.get(url)

    data_path = os.path.join('data', 'submission_pdf')
    os.makedirs(data_path, exist_ok=True)

    with open(os.path.join(data_path, f'{row.submission_number}.pdf'), 'wb') as f:
        f.write(res.content)
    
    print(f'{url} {i+1}/{len(df_submissions)}')
    time.sleep(2)
# Out:
# https://www.accessdata.fda.gov/cdrh_docs/pdf21/K203514.pdf 1/343
# https://www.accessdata.fda.gov/cdrh_docs/pdf21/K202718.pdf 2/343
# https://www.accessdata.fda.gov/cdrh_docs/pdf21/K210484.pdf 3/343
# https://www.accessdata.fda.gov/cdrh_docs/pdf21/K203629.pdf 4/343
# https://www.accessdata.fda.gov/cdrh_docs/pdf21/DEN200069.pdf 5/343
# https://www.accessdata.fda.gov/cdrh_docs/pdf21/K210237.pdf 6/343
# https://www.accessdata.fda.gov/cdrh_docs/pdf21/K210001.pdf 7/343
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/b/develop/medical-ai-evaluation/aiml-database/download-aiml.ipynb Cell 4' in <cell line: 11>()
#      <a href='vscode-notebook-cell:/Users/b/develop/medical-ai-evaluation/aiml-database/download-aiml.ipynb#ch0000006?line=21'>22</a>     f.write(res.content)
#      <a href='vscode-notebook-cell:/Users/b/develop/medical-ai-evaluation/aiml-database/download-aiml.ipynb#ch0000006?line=23'>24</a> print(f'{url} {i+1}/{len(df_submissions)}')
# ---> <a href='vscode-notebook-cell:/Users/b/develop/medical-ai-evaluation/aiml-database/download-aiml.ipynb#ch0000006?line=24'>25</a> time.sleep(2)
#
# KeyboardInterrupt:

# %%
cols = []
data = []

for i, pc in enumerate(product_codes):

    url = product_code_url + pc
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    data_path = os.path.join('data', 'product_code_html')
    os.makedirs(data_path, exist_ok=True)
    
    with open(os.path.join(data_path, f'{pc}.htm'), 'w') as f:
        f.write(str(soup))

    print(url)

#     tables = soup.findAll('table')
#     table = tables[4]

#     if i == 0:
#         for row in table.findAll('tr'):
#             for header in row.findAll('th'):
#                 cols.append(header.text)

#     row_data = []
#     for row in table.findAll('tr'):
#         for header in row.findAll('th'):
#             row_data.append(header.findNext('td').text.replace('\t', '').replace('\n', '').replace('\r', ''))
        
#     data.append(row_data)
#     print(url, len(cols), len(row_data))
#     print(cols)
#     print(row_data)
#     print('---')

# df_products = pd.DataFrame(data, columns=cols)
# df_products.head()
# Out:
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=JAK
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=LLZ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MXD
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PIB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QPF
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QAS
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=KPS
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QIH
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QKB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MUJ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QFM
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QNP
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MQB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QOK
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OEB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=LNH
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QME
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=POK
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QNV
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=NQQ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QNL
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QDQ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=POV
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=JOY
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DQD
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QJU
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DQK
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PRH
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=IYN
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MLO
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QBS
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=IYO
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DSI
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DPS
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=IYE
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MWI
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=BZG
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QEK
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=HAW
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QJB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MRZ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MUD
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=GKZ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=JAA
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PIW
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=GXY
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PLB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PJA
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=JFY
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PBH
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QER
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QAQ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PPU
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OZE
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DQA
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DXH
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=NDC
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QEA
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=POS
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PCS
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OMB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=GWN
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=JIL
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OLO
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=QCC
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=NAY
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OBH
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PNN
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DSB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DRG
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DSH
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=DPT
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MNR
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PTA
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OLZ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=NBW
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MYN
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PBZ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OWB
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=NFJ
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=KPR
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=PEX
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=OIW
# https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpcd/classification.cfm?start_search=1&amp;productcode=MHX
